# %%
# %matplotlib inline
# control_points = [(0, 1), (0, 0), (1, 0), (.5, 1)]

import matplotlib.pyplot as plt
plt.style.use('bmh')

import bezier
import numpy as np
nodes = np.asfortranarray([
    [0.0, 0.625, 1.0, 0.5],
    [0.0, 0.5  , 0.5, 0.3],
])
curve = bezier.Curve(nodes, degree=3)
curve.plot(1024)
# Out:
# <Axes: >
